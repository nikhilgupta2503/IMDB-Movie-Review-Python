# %% [markdown]
# #  IMDB DATA SET

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\Data Analytics\Python Project\IMDB\IMDB-Movie-Data.csv')
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # Displaying the top 10 rows from the data sets

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# # Displaying the Bottom 10 rows from the data sets

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# # Find the Shape of the data sets (Number of rows and coloumns)

# %%
data.shape
print("Number Of Rows: ",data.shape[0])
print("Number Of Coloumns: ",data.shape[1])
# Out:
# Number Of Rows:  1000
# Number Of Coloumns:  12

# %% [markdown]
# # Getting the inforamtion about the dataset like total number of non-null value in each rows and data types of different column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# # Any missing Value in the Data sets

# %%
print("Any missing Value in the Datasets:", data.isnull().values.any())
# Out:
# Any missing Value in the Datasets: True

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
percentage = 100*data.isnull().sum()/len(data)
percentage
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
sns.heatmap(data.isnull(), cmap='coolwarm')
plt.show()

# %% [markdown]
# # Droping the Duplicate Value from the data sets

# %%
up_data = data.dropna(axis=0)
up_data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# # Check For Duplicate Values

# %%
val = up_data.duplicated().any()
print("Any duplicate Value in the Dataset?",val)
# Out:
# Any duplicate Value in the Dataset? False

# %%
up_data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# # Movie Whose Runtime Greater or equal to 180 Min

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Runtime (Minutes)']>= 180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# # Average Movies Rating by Year

# %%
up_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
up_data.groupby('Year')['Votes'].mean().sort_values(ascending = False)
# Out:
# Year
# 2012    290861.483871
# 2006    277232.219512
# 2009    267180.577778
# 2008    266580.145833
# 2007    266530.704545
# 2010    261082.929825
# 2011    259254.736842
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
sns.barplot(x = "Year",y = "Votes",data = up_data)
plt.title("Average Voting By Year")
plt.show()

# %% [markdown]
# # Highest Average Revenue By year

# %%
up_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
up_data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending = False)
# Out:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %%
sns.lineplot(x = 'Year', y= 'Revenue (Millions)',data = up_data)
# Out:
# <Axes: xlabel='Year', ylabel='Revenue (Millions)'>

# %% [markdown]
# # Average Rateing By each Directors

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_20 = up_data.groupby('Director')['Rating'].mean().sort_values(ascending=False).head(20).reset_index()
bottom_20 = up_data.groupby('Director')['Rating'].mean().sort_values(ascending=True).head(20).reset_index()

# %%
axt = sns.barplot(x="Director", y="Rating", data=top_20)
plt.xticks(rotation=90)
plt.title("Top 20 Directors by Average Rating")

# Add bar values to each bar
for bar in axt.containers:
    axt.bar_label(bar, fmt='%.2f', fontsize=7, label_type='edge', color='green', weight='light')

plt.show()

# %%
ax = sns.barplot(x="Director", y="Rating", data=bottom_20)
plt.xticks(rotation=90)
plt.title("Bottom 20 Directors by Average Rating")
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', 
                fontsize=8, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# # Display Top 10 Movie with their Runtime and their Title

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
run_time = up_data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title')

# %%
sns.barplot(x="Runtime (Minutes)", y=run_time.index, data=run_time)
plt.show()

# %% [markdown]
# # Display Number of Movies Per Year

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
up_data['Year'].value_counts()
# sns.countplot(x = 'Year', y = 'counts', data = up_data)
# Out:
# Year
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Year',data = up_data)
plt.xlabel('Year')
plt.ylabel('Count of Titles')
plt.title('Movies per Year')
plt.show()

# %% [markdown]
# # Find The Max Revenue Generated Movie In The Data

# %%
up_data.nlargest(1,'Revenue (Millions)')[["Title", "Revenue (Millions)" ]].set_index("Title")
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63

# %% [markdown]
# # Display Top 10 Highest Rated Movie with Title

# %%
up_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_high = up_data.nlargest(10,'Rating')[['Title','Director','Genre', 'Rating']].set_index("Title")
top_high
# Out:
#                                                Director  \
# Title
# The Dark Knight                       Christopher Nolan
# Inception                             Christopher Nolan
# Interstellar                          Christopher Nolan
# Kimi no na wa                            Makoto Shinkai
# The Intouchables                        Olivier Nakache
# The Prestige                          Christopher Nolan
# The Departed                            Martin Scorsese
# The Dark Knight Rises                 Christopher Nolan
# Whiplash                                Damien Chazelle
# The Lives of Others    Florian Henckel von Donnersmarck
#
#                                          Genre  Rating
# Title
# The Dark Knight             Action,Crime,Drama     9.0
# Inception              Action,Adventure,Sci-Fi     8.8
# Interstellar            Adventure,Drama,Sci-Fi     8.6
# Kimi no na wa          Animation,Drama,Fantasy     8.6
# ...

# %%
sns.barplot(x = 'Rating', y = top_high.index,data = top_high, hue = "Director",dodge= False)
plt.legend(bbox_to_anchor = (1.05,1),loc = 2)
plt.show()

# %% [markdown]
# # Find the Average Rating of Movies By Year

# %%
avg_rating = up_data.groupby('Year')['Rating'].mean().reset_index()
avg_rating
# Out:
#     Year    Rating
# 0   2006  7.143902
# 1   2007  7.140909
# 2   2008  6.708333
# 3   2009  6.911111
# 4   2010  6.894737
# 5   2011  6.945614
# 6   2012  6.933871
# 7   2013  6.832143
# 8   2014  6.822581
# 9   2015  6.674312
# 10  2016  6.644444

# %%
sns.barplot(x="Year", y="Rating", data=avg_rating)
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Rating per Year')
plt.show()

# %% [markdown]
# # Did the Rating Affect the Revenue?

# %%
sns.scatterplot(x = 'Rating' , y = 'Revenue (Millions)', data = up_data)
plt.title("Revenue By Rating")
plt.show()

# %% [markdown]
# # Classify Movie On The Based Of Rating

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def rating_category(rating):
    if rating >= 8:
        return "Excellent"
    elif rating >= 6.5:
        return "Good"
    elif rating >= 4.5:
        return "Average"
    else:
        return "Poor"

up_data['Rating_Category'] = up_data['Rating'].apply(rating_category)
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_19316\2952384972.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   up_data['Rating_Category'] = up_data['Rating'].apply(rating_category)

# %%
up_data.head(20)
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# ...

# %% [markdown]
# # Cout of Action Movies

# %%
up_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Rating_Category'],
#       dtype='object')

# %%
Action_Movie_Count = len(up_data[up_data['Genre'].str.contains('Action',case = False)])

# %%
print("Total No. of Action Movie Are:- ", Action_Movie_Count)
# Out:
# Total No. of Action Movie Are:-  277

# %% [markdown]
# # Unique Value From The Genere

# %%
up_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Rating_Category'],
#       dtype='object')

# %%
up_data['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 993     Action,Adventure,Horror
# 994                      Comedy
# 996                      Horror
# 997         Drama,Music,Romance
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 838, dtype: object

# %%
list1 = []
for value in up_data['Genre']:
    list1.append(value.split(','))
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Comedy'],
# ...

# %%
one_d = []
for item in list1:
    for item1 in item:
        one_d.append(item1)
        
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
# ...

# %%
unique_sets = set(one_d)
unique_Genre = list(unique_sets)
len(unique_list)
unique_Genre
# Out:
# ['Sci-Fi',
#  'Romance',
#  'Fantasy',
#  'Thriller',
#  'Music',
#  'Western',
#  'Crime',
#  'Horror',
#  'Adventure',
#  'Action',
#  'Animation',
#  'Musical',
#  'Sport',
#  'History',
#  'Biography',
#  'Family',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'War']

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 419,
#          'Action': 277,
#          'Comedy': 250,
#          'Adventure': 244,
#          'Thriller': 148,
#          'Crime': 126,
#          'Romance': 120,
#          'Sci-Fi': 107,
#          'Fantasy': 92,
#          'Horror': 87,
#          'Mystery': 86,
#          'Biography': 67,
#          'Family': 48,
#          'Animation': 45,
#          'History': 25,
#          'Music': 15,
#          'Sport': 15,
#          'War': 10,
#          'Musical': 5,
#          'Western': 4})
